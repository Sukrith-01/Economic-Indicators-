# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ## Title: Economic Indicators and Inflation Analysis

# %% [markdown]
# ## Description:
# "Economic Indicators and Inflation Analysis" delves into the critical interplay between essential economic metrics and inflation, providing a thorough investigation of how these factors shape economies at both macro and micro levels. This study examines key economic indicators—such as Gross Domestic Product (GDP) growth, unemployment rates, consumer price indices (CPI), producer price indices (PPI), interest rates, and money supply—and their roles in signaling inflationary pressures or stability. By analyzing historical data, current trends, and predictive models, the work highlights how these indicators influence inflation rates, purchasing power, and overall economic health. It may also explore the impact of fiscal and monetary policies, global market dynamics, and external shocks (e.g., supply chain disruptions or geopolitical events) on inflation. Designed for economists, policymakers, or students of finance, this analysis offers insights into interpreting economic signals, forecasting inflationary trends, and understanding their implications for businesses, consumers, and governments.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv("C:\\Users\\13612\\Downloads\\Economic Indicators And Inflation.csv")

# %%
df.head()
# Out:
#   Country   Year   GDP (in billion USD)   Inflation Rate (%)  \
# 0     USA   2010                15000.0                 1.64
# 1     USA   2011                15500.0                 3.16
# 2     USA   2012                16000.0                 2.07
# 3     USA   2013                16500.0                 1.50
# 4     USA   2014                17000.0                 1.62
#
#     Unemployment Rate (%)   Economic Growth (%)
# 0                    9.63                  2.55
# 1                    8.94                  1.53
# 2                    8.10                  2.28
# 3                    7.70                  1.84
# 4                    7.25                  2.53

# %%
df.tail()
# Out:
#       Country   Year   GDP (in billion USD)   Inflation Rate (%)  \
# 299  Pakistan   2021                  296.0                  8.9
# 300  Pakistan   2022                  350.0                 12.3
# 301  Pakistan   2023                  400.0                 20.0
# 302  Pakistan   2024                  450.0                 25.0
# 303  Pakistan   2025                  500.0                 20.0
#
#       Unemployment Rate (%)   Economic Growth (%)
# 299                     5.0                   5.7
# 300                     5.0                   6.0
# 301                     5.0                   4.0
# 302                     5.0                   3.0
# 303                     5.0                   3.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 304 non-null    object
#  1    Year                   304 non-null    int64
#  2    GDP (in billion USD)   304 non-null    float64
#  3    Inflation Rate (%)     304 non-null    float64
#  4    Unemployment Rate (%)  304 non-null    float64
#  5    Economic Growth (%)    304 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 14.4+ KB

# %%
df.describe()
# Out:
#               Year   GDP (in billion USD)   Inflation Rate (%)  \
# count   304.000000             304.000000           304.000000
# mean   2017.500000            3173.934211            35.531776
# std       4.617373            4365.913537           131.757515
# min    2010.000000               1.000000            -1.200000
# 25%    2013.750000             475.000000             1.635000
# 50%    2017.500000            1900.000000             3.300000
# 75%    2021.250000            3425.000000             5.857500
# max    2025.000000           22500.000000           857.000000
#
#         Unemployment Rate (%)   Economic Growth (%)
# count              304.000000            304.000000
# mean                 6.805493              3.391349
# std                  6.687968              3.626414
# min                  1.600000            -14.000000
# 25%                  4.275000              1.700000
# 50%                  5.400000              2.900000
# ...

# %%
df.corr
# Out:
# <bound method DataFrame.corr of       Country   Year   GDP (in billion USD)   Inflation Rate (%)  \
# 0         USA   2010                15000.0                 1.64
# 1         USA   2011                15500.0                 3.16
# 2         USA   2012                16000.0                 2.07
# 3         USA   2013                16500.0                 1.50
# 4         USA   2014                17000.0                 1.62
# ..        ...    ...                    ...                  ...
# 299  Pakistan   2021                  296.0                 8.90
# 300  Pakistan   2022                  350.0                12.30
# 301  Pakistan   2023                  400.0                20.00
# 302  Pakistan   2024                  450.0                25.00
# 303  Pakistan   2025                  500.0                20.00
#
#       Unemployment Rate (%)   Economic Growth (%)
# 0                      9.63                  2.55
# 1                      8.94                  1.53
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of       Country   Year   GDP (in billion USD)   Inflation Rate (%)  \
# 0         USA   2010                15000.0                 1.64
# 1         USA   2011                15500.0                 3.16
# 2         USA   2012                16000.0                 2.07
# 3         USA   2013                16500.0                 1.50
# 4         USA   2014                17000.0                 1.62
# ..        ...    ...                    ...                  ...
# 299  Pakistan   2021                  296.0                 8.90
# 300  Pakistan   2022                  350.0                12.30
# 301  Pakistan   2023                  400.0                20.00
# 302  Pakistan   2024                  450.0                25.00
# 303  Pakistan   2025                  500.0                20.00
#
#       Unemployment Rate (%)   Economic Growth (%)
# 0                      9.63                  2.55
# 1                      8.94                  1.53
# ...

# %%
df.isnull().sum()
# Out:
# Country                   0
#  Year                     0
#  GDP (in billion USD)     0
#  Inflation Rate (%)       0
#  Unemployment Rate (%)    0
#  Economic Growth (%)      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Country', ' Year', ' GDP (in billion USD)', ' Inflation Rate (%)',
#        ' Unemployment Rate (%)', ' Economic Growth (%)'],
#       dtype='object')

# %% [markdown]
# ## Data Visualization

# %%
df.columns = df.columns.str.strip()

plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x="Year", y="Inflation Rate (%)", hue="Country", marker="o")

plt.title("Inflation Rate Trend Over Time")
plt.xlabel("Year")
plt.ylabel("Inflation Rate (%)")
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="GDP (in billion USD)", y="Inflation Rate (%)", hue="Country", alpha=0.7)
sns.regplot(data=df, x="GDP (in billion USD)", y="Inflation Rate (%)", scatter=False, color='red')

plt.title("Relationship Between GDP and Inflation Rate")
plt.xlabel("GDP (in billion USD)")
plt.ylabel("Inflation Rate (%)")
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
corr_matrix = df[['GDP (in billion USD)', 'Inflation Rate (%)', 
                  'Unemployment Rate (%)', 'Economic Growth (%)']].corr()

# Heatmap visualization
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

plt.title("Correlation Between Economic Indicators")
plt.show()

# %%
year_selected = 2023  # Change this for different years
df_year = df[df["Year"] == year_selected].sort_values("Economic Growth (%)", ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(data=df_year, x="Country", y="Economic Growth (%)", palette="viridis")

plt.title(f"Economic Growth by Country in {year_selected}")
plt.xlabel("Country")
plt.ylabel("Economic Growth (%)")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="GDP (in billion USD)", y="Economic Growth (%)", size="Inflation Rate (%)", hue="Country", alpha=0.7, sizes=(20, 500))

plt.title("GDP vs Economic Growth (Bubble Size = Inflation Rate)")
plt.xlabel("GDP (in billion USD)")
plt.ylabel("Economic Growth (%)")
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# ## ML Algorithms

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.inspection import permutation_importance
import xgboost as xgb

# %%
# Data cleaning (strip column names)
df.columns = df.columns.str.strip()

# Define features and target
features = df[['GDP (in billion USD)', 'Inflation Rate (%)', 'Unemployment Rate (%)', 'Year']]
target = df['Economic Growth (%)']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Define models
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Random Forest": RandomForestRegressor(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(n_estimators=100, random_state=42),
    "SVR": SVR(),
    "KNN": KNeighborsRegressor(n_neighbors=5),
    "XGBoost": xgb.XGBRegressor(n_estimators=100, random_state=42)
}

# Store results
results = {}

# Train and evaluate each model
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    
    results[name] = {"R² Score": r2, "MAE": mae}
    
    print(f"{name} - R² Score: {r2:.4f}, MAE: {mae:.4f}")

# Convert results to DataFrame
results_df = pd.DataFrame(results).T
# Out:
# Linear Regression - R² Score: 0.0060, MAE: 2.9740
# Decision Tree - R² Score: 0.5186, MAE: 1.9866
# Random Forest - R² Score: 0.4255, MAE: 2.0944
# Gradient Boosting - R² Score: 0.4666, MAE: 2.1506
# SVR - R² Score: 0.1910, MAE: 2.4653
# KNN - R² Score: -0.0451, MAE: 2.7409
# XGBoost - R² Score: 0.5327, MAE: 1.9883

# %%
# Convert results to DataFrame
results_df = pd.DataFrame(results).T

# Plot R² Score Comparison
plt.figure(figsize=(12, 6))
sns.barplot(x=results_df.index, y=results_df["R² Score"], palette="coolwarm")
plt.xticks(rotation=45)
plt.title("Model Comparison (R² Score)")
plt.ylabel("R² Score")
plt.xlabel("Model")
plt.ylim(0, 1)
plt.show()

# Plot MAE Comparison
plt.figure(figsize=(12, 6))
sns.barplot(x=results_df.index, y=results_df["MAE"], palette="magma")
plt.xticks(rotation=45)
plt.title("Model Comparison (Mean Absolute Error)")
plt.ylabel("MAE (Lower is better)")
plt.xlabel("Model")
plt.show()

# Ensure all R² scores are non-negative
results_df["R² Score"] = results_df["R² Score"].clip(lower=0)

plt.figure(figsize=(8, 8))
plt.pie(results_df["R² Score"], labels=results_df.index, autopct='%1.1f%%', 
        colors=sns.color_palette("coolwarm", len(results_df)))
plt.title("Model Accuracy Percentage (Based on R² Score)")
plt.show()


# Compute permutation importance for the best model (highest R²)
best_model_name = results_df["R² Score"].idxmax()
best_model = models[best_model_name]

perm_importance = permutation_importance(best_model, X_test, y_test, n_repeats=10, random_state=42)
sorted_idx = perm_importance.importances_mean.argsort()

# Plot Feature Importance
plt.figure(figsize=(8, 6))
plt.barh(features.columns[sorted_idx], perm_importance.importances_mean[sorted_idx], color='royalblue')
plt.xlabel('Permutation Importance')
plt.title(f'Feature Importance for {best_model_name}')
plt.show()
